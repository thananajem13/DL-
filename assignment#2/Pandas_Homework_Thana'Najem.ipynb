# %% [markdown]
# # Homework
#
# **`step one`**:
# \
# save a copy of the notebook in your drive and save it by your name: <pandas_HW_\<ur name>
#
# \
#
# using the heart disease dataset:
#
# - load the dataset csv file into a pandas dataframe
# - print the dataframe
# - remove the id column from the data frame
# - split the following columns {age, gender, height, width, cholesterol, smoke} into a seprate dataframe
# - split the cardio column into a seprate data series and convert it to dummy variable dataframe
# - preprocess the features by applying standarization and normalization
# - preprocess the target by applying one hot encoding

# %%
import pandas as pd
import seaborn as sns       # use it to plot confusion matrix of correlation

# %%
# data link
dlink = "https://raw.githubusercontent.com/caravanuden/cardio/master/cardio_train.csv"

#load the dataset csv file into a pandas dataframe
df = pd.read_csv(dlink, delimiter=";")

# print the dataframe
df
# Out:
#           id    age  gender  height  weight  ...  gluc  smoke  alco  active  cardio
# 0          0  18393       2     168    62.0  ...     1      0     0       1       0
# 1          1  20228       1     156    85.0  ...     1      0     0       1       1
# 2          2  18857       1     165    64.0  ...     1      0     0       0       1
# 3          3  17623       2     169    82.0  ...     1      0     0       1       1
# 4          4  17474       1     156    56.0  ...     1      0     0       0       0
# ...      ...    ...     ...     ...     ...  ...   ...    ...   ...     ...     ...
# 69995  99993  19240       2     168    76.0  ...     1      1     0       1       0
# 69996  99995  22601       1     158   126.0  ...     2      0     0       1       1
# 69997  99996  19066       2     183   105.0  ...     1      0     1       0       1
# 69998  99998  22431       1     163    72.0  ...     2      0     0       0       1
# 69999  99999  20540       1     170    72.0  ...     1      0     0       1       0
#
# [70000 rows x 13 columns]

# %%
#########################################
######### write your code here ##########
#########################################

# drop the id column
df.drop(['id'],axis=1,inplace=True)
df
# Out:
#          age  gender  height  weight  ap_hi  ...  gluc  smoke  alco  active  cardio
# 0      18393       2     168    62.0    110  ...     1      0     0       1       0
# 1      20228       1     156    85.0    140  ...     1      0     0       1       1
# 2      18857       1     165    64.0    130  ...     1      0     0       0       1
# 3      17623       2     169    82.0    150  ...     1      0     0       1       1
# 4      17474       1     156    56.0    100  ...     1      0     0       0       0
# ...      ...     ...     ...     ...    ...  ...   ...    ...   ...     ...     ...
# 69995  19240       2     168    76.0    120  ...     1      1     0       1       0
# 69996  22601       1     158   126.0    140  ...     2      0     0       1       1
# 69997  19066       2     183   105.0    180  ...     1      0     1       0       1
# 69998  22431       1     163    72.0    135  ...     2      0     0       0       1
# 69999  20540       1     170    72.0    120  ...     1      0     0       1       0
#
# [70000 rows x 12 columns]

# %%
# split the following columns {age, gender, height, width, cholesterol, smoke} into a seprate dataframe 

names = ["age", "gender", "height", "weight", "cholesterol", "smoke"]
new_df = pd.DataFrame(df, columns=names)
new_df
# Out:
#          age  gender  height  weight  cholesterol  smoke
# 0      18393       2     168    62.0            1      0
# 1      20228       1     156    85.0            3      0
# 2      18857       1     165    64.0            3      0
# 3      17623       2     169    82.0            1      0
# 4      17474       1     156    56.0            1      0
# ...      ...     ...     ...     ...          ...    ...
# 69995  19240       2     168    76.0            1      1
# 69996  22601       1     158   126.0            2      0
# 69997  19066       2     183   105.0            3      0
# 69998  22431       1     163    72.0            1      0
# 69999  20540       1     170    72.0            2      0
#
# [70000 rows x 6 columns]

# %%
# split the cardio column into a seprate data series and convert it to dummy variable dataframe
# 1. split the cardio column into a seprate data series
target = df.pop('cardio')

# %%
# 2. preprocess the target by applying one hot encoding 

dummy_target = pd.get_dummies(target)
dummy_target
# Out:
#        0  1
# 0      1  0
# 1      0  1
# 2      0  1
# 3      0  1
# 4      1  0
# ...   .. ..
# 69995  1  0
# 69996  0  1
# 69997  0  1
# 69998  0  1
# 69999  1  0
#
# [70000 rows x 2 columns]

# %%
# preprocess the features by applying standarization the src dataframe
stand_df = (df - df.mean())/df.std()
stand_df
# Out:
#             age    gender    height  ...     smoke      alco    active
# 0     -0.436058  1.364045  0.443449  ... -0.310877 -0.238383  0.494164
# 1      0.307684 -0.733103 -1.018161  ... -0.310877 -0.238383  0.494164
# 2     -0.247995 -0.733103  0.078046  ... -0.310877 -0.238383 -2.023592
# 3     -0.748147  1.364045  0.565250  ... -0.310877 -0.238383  0.494164
# 4     -0.808538 -0.733103 -1.018161  ... -0.310877 -0.238383 -2.023592
# ...         ...       ...       ...  ...       ...       ...       ...
# 69995 -0.092761  1.364045  0.443449  ...  3.216661 -0.238383  0.494164
# 69996  1.269483 -0.733103 -0.774559  ... -0.310877 -0.238383  0.494164
# 69997 -0.163285  1.364045  2.270461  ... -0.310877  4.194876 -2.023592
# 69998  1.200580 -0.733103 -0.165555  ... -0.310877 -0.238383 -2.023592
# 69999  0.434141 -0.733103  0.687051  ... -0.310877 -0.238383  0.494164
#
# [70000 rows x 11 columns]

# %%
# preprocess the features by applying normalization on the src dataframe

normed_df = (stand_df - stand_df.min()) / (stand_df.max() - stand_df.min())
normed_df
# Out:
#             age  gender    height    weight  ...  gluc  smoke  alco  active
# 0      0.588076     1.0  0.579487  0.273684  ...   0.0    0.0   0.0     1.0
# 1      0.730159     0.0  0.517949  0.394737  ...   0.0    0.0   0.0     1.0
# 2      0.624003     0.0  0.564103  0.284211  ...   0.0    0.0   0.0     0.0
# 3      0.528455     1.0  0.584615  0.378947  ...   0.0    0.0   0.0     1.0
# 4      0.516918     0.0  0.517949  0.242105  ...   0.0    0.0   0.0     0.0
# ...         ...     ...       ...       ...  ...   ...    ...   ...     ...
# 69995  0.653659     1.0  0.579487  0.347368  ...   0.0    1.0   0.0     1.0
# 69996  0.913899     0.0  0.528205  0.610526  ...   0.5    0.0   0.0     1.0
# 69997  0.640186     1.0  0.656410  0.500000  ...   0.0    0.0   1.0     0.0
# 69998  0.900736     0.0  0.553846  0.326316  ...   0.5    0.0   0.0     0.0
# 69999  0.754317     0.0  0.589744  0.326316  ...   0.0    0.0   0.0     1.0
#
# [70000 rows x 11 columns]

# %%
# compute correlation between all features
df['cardio'] = target
sns.set(rc={'figure.figsize':[15,15]})
corrMatrix = df[11:-1].corr()
print(corrMatrix,type(corrMatrix))
sns.heatmap(corrMatrix, annot=True)
# Out:
#                   age    gender    height  ...      alco    active    cardio
# age          1.000000 -0.022790 -0.081539  ... -0.029716 -0.009944  0.238212
# gender      -0.022790  1.000000  0.499012  ...  0.170971  0.005779  0.008039
# height      -0.081539  0.499012  1.000000  ...  0.094421 -0.006655 -0.010879
# weight       0.053624  0.155395  0.290967  ...  0.067118 -0.016977  0.181632
# ap_hi        0.020765  0.006000  0.005484  ...  0.001407 -0.000042  0.054466
# ap_lo        0.017650  0.015246  0.006146  ...  0.010597  0.004767  0.065713
# cholesterol  0.154350 -0.035784 -0.050223  ...  0.035795  0.009937  0.221135
# gluc         0.098644 -0.020558 -0.018648  ...  0.011249 -0.006769  0.089275
# smoke       -0.047625  0.338152  0.187999  ...  0.340086  0.025843 -0.015505
# alco        -0.029716  0.170971  0.094421  ...  1.000000  0.025465 -0.007344
# active      -0.009944  0.005779 -0.006655  ...  0.025465  1.000000 -0.035705
# cardio       0.238212  0.008039 -0.010879  ... -0.007344 -0.035705  1.000000
#
# [12 rows x 12 columns] <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Bonus Tasks

# %% [markdown]
# ## Rescale the age
# Map the age column from days to years

# %%
# Map the age column from days to years

df.apply(lambda x: pd.Series(x/365.0, index=['age']), axis=1)
# Out:
#              age
# 0      50.391781
# 1      55.419178
# 2      51.663014
# 3      48.282192
# 4      47.873973
# ...          ...
# 69995  52.712329
# 69996  61.920548
# 69997  52.235616
# 69998  61.454795
# 69999  56.273973
#
# [70000 rows x 1 columns]

# %% [markdown]
# ## confusion matrix
#
#
# hint
# > use seaborn to help you here
#
# ![image.png](data:image/png;base64,...)

# %%
# draw the confusion matrix of the features correlation 
sns.set(rc={'figure.figsize':[15,15]})
corrMatrix = df[11:-1].corr()
sns.heatmap(corrMatrix, annot=True) 

"""
weight, age and cholestrol features affect on cardio disease
"""
"""
sns.set(rc={'figure.figsize':[15,15]})
corrMatrix = df[(df>=0.5) & (df<=1) | (df<=-0.5)&(df>=-1)].corr()
sns.heatmap(corrMatrix, annot=True) 
"""
# Out:
# "\nsns.set(rc={'figure.figsize':[15,15]})\ncorrMatrix = df[(df>=0.5) & (df<=1) | (df<=-0.5)&(df>=-1)].corr()\nsns.heatmap(corrMatrix, annot=True) \n"

# %% [markdown]
# ## Features Histogram
# Plot the histogram for all the feature in the dataframe
#
# ![image.png](data:image/png;base64,...)

# %%
# plot the histogram of all feature in the dataframe
sns.set(rc={'figure.figsize':[20,20]})
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c8a940b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c6c21c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c705f198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c6c5c860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c6bcdf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c6daf940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c9580550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1dff35320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1dff35eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c4655128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c652d828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa1c4ad9278>]],
#       dtype=object)
