# %% [markdown]
# <a href="https://colab.research.google.com/github/thananajem13/DL-/blob/main/ThanaNajemHomeWorkLec_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import requests
# import numpy as np
# import matplotlib.pyplot as plt
# from PIL import Image
# from io import BytesIO
#
# img_url = "https://i.pinimg.com/originals/60/74/aa/6074aa58b290f75fe8a7bf82c548676d.jpg"
# response = requests.get(img_url)    # using get request to download the image into buffer
#
# raw_img = BytesIO(response.content) # extracting the image as bytes from the response buffer
# print(type(raw_img))
#
# # converting the image into PIL.Image object then casting it into numpy.ndarray
# # used the copy to deep copy the image array since the image source isn't writable
# src_img = np.uint8(Image.open(raw_img)).copy()
# print(src_img.shape)
#
# # displaying the image
# plt.imshow(src_img)
#
# # printing the array state to ensure it is writable
# src_img.flags   # you can comment the copy() and test the output flags# Exercise
#
# > **RGB-Image Formation**
# RGB image formed by stacking $3×2D$-*Matrices* of the same shape producing a colored image:
# \
# each matrix is containing the light intensity values of each color channel
#
# <br>
#
# <img src="https://savan77.github.io/assets/img/3channles.png">
# <img width="50%" src="https://ai.stanford.edu/~syyeung/cvweb/Pictures1/colorpixels.png">
# <br>
# <img src="https://miro.medium.com/max/693/1*bV7S0zACdidh11ikjYpLpQ.png">
#
# ---
#
# <br><br><br>
# **To Do**
#
# >    - using np.zeros(image_shape) create a black image
# >    - using numpy indexing to draw a white square in the image
# >    - using np.dstack to make it a colored image
# >    - change the square color to any color between $\{R, G, B\}$
#
# **Given**
# >    -  img_size = (192, 192)
# >    -  square_length = 64
#
# \
#
# **output**:
#
# <table>
#     <tr>
#         <th>expected output</th>
#         <th>bonus</th>
#     </tr>
#     <tr>
#         <td><img src="data:image/png;base64,..."></td>
#         <td><img src="data:image/png;base64,..."></td>
#     </tr>
# </table>
# <br>
#
# hint to display image use:
#
# ```python
#     plt.imshow(img)
# ```

# %%
import requests
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO 

img_url = "https://upload.wikimedia.org/wikipedia/commons/a/ac/Blue%2C_red_and_green_parrot_%28Unsplash%29.jpg"
response = requests.get(img_url)    # using get request to download the image into buffer

raw_img = BytesIO(response.content) # extracting the image as bytes from the response buffer
print(type(raw_img))

# converting the image into PIL.Image object then casting it into numpy.ndarray
# used the copy to deep copy the image array since the image source isn't writable
src_img = np.uint8(Image.open(raw_img)).copy()      
print(src_img.shape)

# displaying the image
plt.imshow(src_img)

# printing the array state to ensure it is writable
src_img.flags   # you can comment the copy() and test the output flags
# Out:
# <class '_io.BytesIO'>
# (2999, 4498, 3)
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
plt.imshow(src_img[:,:,0], cmap='Reds')

# %%
plt.imshow(src_img[:,:,1], cmap='Greens')

# %%
plt.imshow(src_img[:,:,2], cmap='Blues')

# %%
plt.imshow(src_img[:,:,0], cmap='gray')

# %%
plt.imshow(src_img[:,:,1], cmap='gray')

# %%
plt.imshow(src_img[:,:,2], cmap='gray')

# %% [markdown]
# # New Section

# %%
#########################################
######### write your code here ##########
#########################################
import numpy as np
import matplotlib.pyplot as plt
img_shape = (192,192)
box_length = 64
img1 = np.zeros(img_shape,"uint8")
img=np.dstack([img1]*3)
img[:64,0:64] = [255,0,0]
img[64:128,64:128] = [0,255,0]
img[128:192,128:192] = [0,0,255]
plt.imshow(img,"gray")
img.shape
# Out:
# (192, 192, 3)
